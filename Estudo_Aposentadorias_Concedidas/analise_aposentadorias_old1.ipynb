# %% [markdown]
# # Análise do dados de Aposentadorias concedidas por anos de serviço.

# %% [markdown]
# # 1. Introdução
#  - Informação sobre o dataset: Este dataset foi retirado do site do data rio (fonte abaixo). Ele contém informações sobre a execução orçamentária do Município do Rio. Os dados compreendem o período de 2008 até início de 2019.<br>
# Infelizmente não encontrei um dicionário para descrever melhor os atributos. <br>
#     Fonte dos dados: http://www.data.rio/datasets/execu%C3%A7%C3%A3o-or%C3%A7ament%C3%A1ria-despesas <br>
#
# # 2. Bibliotecas
#  - Importação das Bibliotecas utilizadas <br>
#  - Importação do Dataset <br>
#
# # 3. Conhecendo um pouco os dados
#  - Shape do dataset  <br>
#  - Atributos do Dataset  <br>
#  - Olhando as primeiras linhas <br>
#  - Atributos do Dataset <br>
#  - Verificando valores nulos  <br>
#  - Verificando valores N/A (não disponível) <br>
#  - Olhando os tipos dos dados e formato dos dados <br>
#  - Verificando os valores únicos <br>

# %% [markdown]
# # 4. Explorandos os dados
# - Verificando os Totais por Exercicio. <br>
# - Plotando a distribuição dos valores por Exercício. <br>
# - Plotando a proporção dos valores por Exercício <br>
# - Plotando alguns gráficos com diferentes agrupamentos. <br>

# %% [markdown]
# # ** Vamos começar a brincadeira! **

# %% [markdown]
# # 1. Introdução:
# <h3>Contexto</h3>
#
#     ** O principal objetivo deste notebook é praticar o uso do python para análise e visualização de dados. **
#
# O conjunto de dados original contém 156.924 linhas com 21 atributos. Alguns atributos contém apenas o código utilizado pelo município, infelizmente não consegui encontrar a decrição destes códigos.
#
# <h3>Conteúdo</h3>
# É um pouco difícil entender o conjunto de dados sem um dicionário. Porém mesmo não compreendendo totalmente o dataset (o que não é muito recomendado), decidi prosseguir com a análise, pois como dito anteriormente, o objetivo é praticar o uso do python para análise e visualização de dados.
#
# Foram criadas algumas funções para agregar, organizar e plotar gráficos flexibilizando a visualização dos dados de várias maneiras.
#
# Por exemplo:
#  - Podemos pegar qualquer atributo e valor e plotar visões gráficas dos tops itens deste atributo de maior valor e agrupar os demais itens em “Outros”;
#  - Também podemos a partir de qualquer atributo pegar todos os valores (métricas) e visualizar o gráfico a distribuição dos valores dos tops itens deste atributo.

# %% [markdown]
# # 2. Bibliotecas
# 2.1 - Importação das Bibliotecas utilizadas <br>
# 2.2 - Importação do Dataset <br>

# %%
# Carregando das bibliotecas
import pandas as pd 
import locale
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tools
#warnings.filterwarnings("ignore")
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Importando os dados.
df_aposentadorias = pd.read_csv('./base_dados/CON06-Aposentadorias_concedidas_anos_servico.csv',  encoding = "ISO-8859-1", decimal=",", na_values='-', skipfooter=1, engine='python')

# %% [markdown]
#
# # 3. Conhecendo um pouco os dados
#  - Shape do dataset  <br>
#  - Atributos do Dataset  <br>
#  - Olhando as primeiras linhas <br>
#  - Atributos do Dataset <br>
#  - Verificando valores nulos  <br>
#  - Verificando valores N/A (não disponível) <br>
#  - Olhando os tipos dos dados e formato dos dados <br>
#  - Verificando os valores únicos <br>

# %%
# Shape do dataset original
df_aposentadorias.shape
# Out:
# (3879, 8)

# %%
# Atributos do Dataset
df_aposentadorias.columns
# Out:
# Index(['Ano', 'Espécie', 'Anos de Serviço do Segurado', 'Sexo', 'Clientela',
#        'Qte Benefícios Concedidos', 'Vlr Benefícios Concedidos (R$)',
#        'Vlr Benef Concedidos (Mil R$)'],
#       dtype='object')

# %%
# Remove colunas que não serão utilizadas
df_aposentadorias.drop(columns=['Vlr Benef Concedidos (Mil R$)'], inplace=True)

# %%
# Olhando os tipos dos dados e formato dos dados
df_aposentadorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3879 entries, 0 to 3878
# Data columns (total 7 columns):
# Ano                               3879 non-null int64
# Espécie                           3879 non-null object
# Anos de Serviço do Segurado       3879 non-null object
# Sexo                              3879 non-null object
# Clientela                         3879 non-null object
# Qte Benefícios Concedidos         3879 non-null int64
# Vlr Benefícios Concedidos (R$)    3879 non-null float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 212.2+ KB

# %%
# Olhando as primeiras linhas antes das conversões
df_aposentadorias.head()
# Out:
#     Ano                       Espécie Anos de Serviço do Segurado       Sexo  \
# 0  1996      42-Ap Tempo Contrib Lops                 Até 15 Anos  Masculino
# 1  1996      42-Ap Tempo Contrib Lops                 Até 15 Anos   Feminino
# 2  1996  46-Ap Tempo Contrib Especial                 Até 15 Anos  Masculino
# 3  1996  46-Ap Tempo Contrib Especial                 Até 15 Anos   Feminino
# 4  1996       Outras Ap Tempo Contrib                 Até 15 Anos  Masculino
#
#   Clientela  Qte Benefícios Concedidos  Vlr Benefícios Concedidos (R$)
# 0    Urbana                          0                            0.00
# 1    Urbana                          0                            0.00
# 2    Urbana                         48                        26860.22
# 3    Urbana                          0                            0.00
# 4    Urbana                         41                        18272.77

# %%
# Convertendo os tipos de algumas colunas.
df_aposentadorias['Anos de Serviço do Segurado'] = df_aposentadorias['Anos de Serviço do Segurado'] .astype('category')
df_aposentadorias['Espécie'] = df_aposentadorias['Espécie'] .astype('category')
df_aposentadorias['Sexo'] = df_aposentadorias['Sexo'] .astype('category')
df_aposentadorias['Clientela'] = df_aposentadorias['Clientela'] .astype('category')
df_aposentadorias['Ano'] = df_aposentadorias['Ano'].astype('int', copy=False)

# %%
# Olhando as primeiras linhas apóes as conversões
df_aposentadorias.head()
# Out:
#     Ano                       Espécie Anos de Serviço do Segurado       Sexo  \
# 0  1996      42-Ap Tempo Contrib Lops                 Até 15 Anos  Masculino
# 1  1996      42-Ap Tempo Contrib Lops                 Até 15 Anos   Feminino
# 2  1996  46-Ap Tempo Contrib Especial                 Até 15 Anos  Masculino
# 3  1996  46-Ap Tempo Contrib Especial                 Até 15 Anos   Feminino
# 4  1996       Outras Ap Tempo Contrib                 Até 15 Anos  Masculino
#
#   Clientela  Qte Benefícios Concedidos  Vlr Benefícios Concedidos (R$)
# 0    Urbana                          0                            0.00
# 1    Urbana                          0                            0.00
# 2    Urbana                         48                        26860.22
# 3    Urbana                          0                            0.00
# 4    Urbana                         41                        18272.77

# %%
# Olhando os tipos dos dados e formato dos dados após as conversões
df_aposentadorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3879 entries, 0 to 3878
# Data columns (total 7 columns):
# Ano                               3879 non-null int64
# Espécie                           3879 non-null category
# Anos de Serviço do Segurado       3879 non-null category
# Sexo                              3879 non-null category
# Clientela                         3879 non-null category
# Qte Benefícios Concedidos         3879 non-null int64
# Vlr Benefícios Concedidos (R$)    3879 non-null float64
# dtypes: category(4), float64(1), int64(2)
# memory usage: 107.9 KB

# %%
# Verificando valores nulos
df_aposentadorias.isnull().sum()
# Out:
# Ano                               0
# Espécie                           0
# Anos de Serviço do Segurado       0
# Sexo                              0
# Clientela                         0
# Qte Benefícios Concedidos         0
# Vlr Benefícios Concedidos (R$)    0
# dtype: int64

# %%
# Verificando valores N/A (não disponível)
df_aposentadorias.isna().sum()
# Out:
# Ano                               0
# Espécie                           0
# Anos de Serviço do Segurado       0
# Sexo                              0
# Clientela                         0
# Qte Benefícios Concedidos         0
# Vlr Benefícios Concedidos (R$)    0
# dtype: int64

# %%
# Verificando os valores únicos
df_aposentadorias.nunique()
# Out:
# Ano                                 21
# Espécie                              3
# Anos de Serviço do Segurado         28
# Sexo                                 2
# Clientela                            2
# Qte Benefícios Concedidos          907
# Vlr Benefícios Concedidos (R$)    3000
# dtype: int64

# %%
# Observando algumas medidas
df_aposentadorias.describe()
# Out:
#                Ano  Qte Benefícios Concedidos  Vlr Benefícios Concedidos (R$)
# count  3879.000000                3879.000000                    3.879000e+03
# mean   2005.869812                1353.958237                    1.633005e+06
# std       6.170127                6659.709991                    9.881115e+06
# min    1996.000000                   0.000000                   -1.754886e+05
# 25%    2000.000000                   1.000000                    6.780000e+02
# 50%    2005.000000                   7.000000                    9.135360e+03
# 75%    2011.000000                 103.500000                    1.311362e+05
# max    2016.000000              127300.000000                    2.778605e+08

# %% [markdown]
# # 4. Explorandos os dados
# - Verificando os Totais por Exercicio. <br>
# - Plotando a distribuição dos valores por Exercício. <br>
# - Plotando a proporção dos valores por Exercício <br>
# - Plotando alguns gráficos com diferentes agrupamentos. <br>

# %%
# Benefícios Concedidos por Ano

trace1 = go.Bar(
            x = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].index.values,
            y = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].values,
            name='Ano',
            marker=dict( color='indianred'),  
            )

data = [trace1]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Ano', tickmode='linear'),title='Benefícios Concedidos por Ano')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
# Valor dos Benefícios Concedidos (R$)
trace1 = go.Bar(
            x = df_aposentadorias.groupby('Ano').sum()['Vlr Benefícios Concedidos (R$)'].index.values,
            y = df_aposentadorias.groupby('Ano').sum()['Vlr Benefícios Concedidos (R$)'].values,
            name='Ano',
            marker=dict(color='dodgerblue'),  
            )

data = [trace1]
layout = go.Layout(yaxis=dict(title='R$'),xaxis=dict(title='Ano', tickmode='linear'),title='Valor Benefícios Concedidos (R$)')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
# Distribuição por Sexo
labels = df_aposentadorias['Sexo']
values = df_aposentadorias.groupby('Sexo').sum()['Qte Benefícios Concedidos']

trace = go.Pie(labels=labels, values=values,
              marker=dict(colors=['lightskyblue', 'pink']), 
              )

layout = go.Layout(yaxis=dict(title='Sexo'),xaxis=dict(title='Qtd') ,title='Distribuição por Sexo',autosize=False,     width=800,     height=500 )

fig = go.Figure(data=[trace], layout=layout, )

py.iplot(fig, filename='basic_pie_chart')

# %%
# Dividindo o Dataframe original em dataframes espeícificos.

df_masculino = df_aposentadorias[df_aposentadorias["Sexo"]== 'Masculino']
df_feminino = df_aposentadorias[df_aposentadorias["Sexo"]== 'Feminino']
               
df_urbana = df_aposentadorias[df_aposentadorias["Clientela"]== 'Urbana']
df_rural = df_aposentadorias[df_aposentadorias["Clientela"]== 'Rural']

# %%
# Distribuição por Sexo
dados1 = df_masculino['Qte Benefícios Concedidos'].sum()
dados2 = df_feminino['Qte Benefícios Concedidos'].sum()

trace0 = go.Bar(
            x = [dados1], 
            y = ['Masculino'], 
            name='Masculino',
            textposition = 'auto',
            text=[dados1],
             marker=dict(color='lightskyblue'),  
            orientation = 'h',
    )

trace1 = go.Bar(
            x = [dados2],
            y = ['Feminino'],
            name='Feminino',
            textposition = 'auto',
            text=[dados2],  
            marker=dict(color='pink'),  
            orientation = 'h',
            )

data = [trace0, trace1]
layout = go.Layout(     yaxis=dict(title='Sexo'),xaxis=dict(title='Qtd') ,title='Distribuição por Sexo',autosize=False,     width=800,     height=500 )
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='horizontal-bar', )

# %%
# Benefícios Concedidos por Ano e Sexo
label1 = df_masculino.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
label2 = df_feminino.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
dados1 = df_masculino.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_feminino.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values

trace1 = go.Scatter(
            x =label1,
            y = dados1,
            name='Masculino',
            marker=dict(color='lightskyblue'),  
            fill='tozeroy',
            )


trace2 = go.Scatter(
            x =label2, 
            y =dados2,
            name='Feminino',
            marker=dict(color='pink'),
            fill='tozeroy',
            )


data = [trace1, trace2]
layout = go.Layout( yaxis=dict(title='Qtd'),xaxis=dict(title='Ano', tickmode='linear'),title='Benefícios Concedidos por Ano e Sexo')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
# Distribuição por Clientela
label1 = ['Urbana']
label2 = ['Rural']
dados1 = [df_urbana['Qte Benefícios Concedidos'].sum()]
dados2 = [df_rural['Qte Benefícios Concedidos'].sum()]

trace1 = go.Bar(
            x = dados1,
            y = label1,
            name='Urbana',
            textposition = 'auto',
            text=dados1,  
            marker=dict(color='silver'),  
            orientation = 'h',
            )

trace2 = go.Bar(
            x = dados2,
            y = label2,
            name='Rural',
            textposition = 'auto',
            text=dados2,
            marker=dict(color='seagreen'), 
            orientation = 'h',
            )


data = [trace1, trace2]
layout = go.Layout(     yaxis=dict(title='Clientela') ,xaxis=dict(title='Qtd'),title='Distribuição por Clientela',     autosize=False,     width=800,     height=500 )
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar', )

# %%
# Benefícios Concedidos por Ano e Clientela

label1 = df_urbana.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
label2 = df_rural.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
dados1 = df_urbana.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_rural.groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values

trace1 = go.Bar(
            x =label1,
            y =dados1,
            name='Urbana',
            textposition = 'auto',
            text=dados1, 
            marker=dict(color='silver'),  
            
            )


trace2 = go.Bar(
            x =label2, 
            y =dados2,
            name='Rural',
            textposition = 'auto',
            text=dados2, 
            marker=dict(color='seagreen'), 
            )


data = [trace1, trace2]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Ano', tickmode='linear'),title='Benefícios Concedidos por Ano e Clientela')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
#Anos de Serviço do Segurado
label1 = df_aposentadorias['Anos de Serviço do Segurado'].unique()
dados1 = df_aposentadorias.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos']


trace1 = go.Bar(
            x =label1,
            y =dados1,
            name='Anos de Serviço do Segurado',
            textposition = 'auto',
            text=dados1, 
            marker=dict(color='tan'),  
            
            )


data = [trace1]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Anos de Serviço do Segurado', tickmode='linear'),title='Distribuição dos Anos de Serviço do Segurado')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
# Trata algumas colunas
df_beneficio = df_aposentadorias[df_aposentadorias['Qte Benefícios Concedidos'] > 0]
df_beneficio = df_beneficio[df_beneficio['Anos de Serviço do Segurado'] != 'Ignorado']
df_beneficio = df_beneficio[df_beneficio['Anos de Serviço do Segurado'] != '{ñ class}']
df_beneficio = df_beneficio.replace('Até 15 Anos', '0 a 15 Anos')

# Plota piramide da Distribuição Sexo por Anos de Serviço

label1 = df_beneficio['Anos de Serviço do Segurado'].unique()

masculino = df_beneficio[df_beneficio["Sexo"]== 'Masculino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values
feminino = df_beneficio[df_beneficio["Sexo"]== 'Feminino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values


layout = go.Layout(yaxis=go.layout.YAxis(title='Anos de Serviço'),
                   xaxis=go.layout.XAxis(title='Qtd'),
                   barmode='overlay',
                   bargap=0.1,
                  title='Distribuição Sexo por Anos de Serviço')


trace1 = go.Bar(y = label1,
            x = masculino *-1,
            name='Masculino',
            orientation='h',
            hoverinfo='x',
            marker=dict(color='lightskyblue'),  
            )
trace2 = go.Bar(y =label1,
            x = feminino,            
            name='Feminino',
            orientation='h',
            text=-1 * dados2.astype('int'),
            hoverinfo='text',
            marker=dict(color='pink'),  
            )

data = [trace1, trace2]

py.iplot( dict(data=data, layout=layout) )

# %%
#Anos de Serviço do Segurado por Clientela

label1 = df_urbana.groupby(['Anos de Serviço do Segurado']).count().sort_index().index
label2 = df_rural.groupby(['Anos de Serviço do Segurado']).count().sort_index().index
dados1 = df_urbana.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_rural.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values

trace1 = go.Bar(
            x =label1,
            y =dados1,
            name='Urbana',
            textposition = 'auto',
            text=dados1,
            marker=dict(color='silver'),  
            
            )
trace2 = go.Bar(
            x = label2 ,
            y = dados2,
            name='Rural',
            textposition = 'auto',
            text=dados2,
            marker=dict(color='seagreen'),  
            
            )

data = [trace1, trace2]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Anos de Serviço do Segurado', tickmode='linear'),title='Distribuição dos Anos de Serviço do Segurado por Clientela')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
#Anos de Serviço do Segurado por Sexo
label1 = df_masculino.groupby(['Anos de Serviço do Segurado']).count().sort_index().index 
label2 = df_feminino.groupby(['Anos de Serviço do Segurado']).count().sort_index().index
dados1 = df_masculino.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_feminino.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values


trace1 = go.Bar(
            x = label1,
            y = dados1,
            name='Masculino',
            textposition = 'auto',
            text= dados1, 
            marker=dict(color='lightskyblue'),  
            
            )
trace2 = go.Bar(
            x = label2,
            y = dados2,
            name='Feminino',
            textposition = 'auto',
            text= dados2, 
            marker=dict(color='pink'),  
            
            )

data = [trace1, trace2]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Anos de Serviço do Segurado', tickmode='linear'),title='Distribuição dos Anos de Serviço do Segurado por Sexo')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
#Distribuição Espécie
label1 = ['42-Ap Tempo Contrib Lops']
label2 = ['46-Ap Tempo Contrib Especial']
label3 = ['Outras Ap Tempo Contrib']
dados1 = [df_aposentadorias[df_aposentadorias['Espécie']== '42-Ap Tempo Contrib Lops']['Qte Benefícios Concedidos'].sum()]
dados2 = [df_aposentadorias[df_aposentadorias['Espécie']== '46-Ap Tempo Contrib Especial']['Qte Benefícios Concedidos'].sum()]
dados3 = [df_aposentadorias[df_aposentadorias['Espécie']== 'Outras Ap Tempo Contrib']['Qte Benefícios Concedidos'].sum()]

trace1 = go.Bar(
            x = label1,
            y = dados1,
            name='42-Ap Tempo Contrib Lops',
            textposition = 'auto',
            text= dados1,
            marker=dict(color='khaki'),  
            
            )

trace2 = go.Bar(
            x =label2,
            y =dados2,
            name='46-Ap Tempo Contrib Especial',
            textposition = 'auto',
            text=dados2,
            marker=dict(color='lightsteelblue'),  
            
            )

trace3 = go.Bar(
            x =label3 ,
            y =dados3,
            name='Outras Ap Tempo Contrib',
            textposition = 'auto',
            text=dados3,
            marker=dict(color='lightgreen'),  
            
            )


data = [trace1, trace2, trace3]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Espécie', tickmode='linear'),title='Distribuição Espécie')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
#Distribuição da Espécie por Sexo
label1 = df_masculino.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].sort_index().index
label2 = df_feminino.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].sort_index().index
dados1 = df_masculino.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_feminino.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].values


trace1 = go.Bar(
            x = label1,
            y = dados1,
            name='Masculino',
            textposition = 'auto',
            text=dados1, 
            marker=dict(
            color='lightskyblue'),  
            
            )
trace2 = go.Bar(
            x =label2,
            y = dados2 ,
            name='Feminino',
            textposition = 'auto',
            text=dados2, 
            marker=dict(color='pink'),  
            
            )

data = [trace1, trace2]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Espécie', tickmode='linear'),title='Distribuição da Espécie por Sexo')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
#Distribuição da Espécie por Clientela

label1 = df_urbana.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].sort_index().index
label2 = df_rural.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].sort_index().index
dados1 = df_urbana.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_rural.groupby(['Espécie']).sum()['Qte Benefícios Concedidos'].values

trace1 = go.Bar(
            x = label1,
            y = dados1,
            name='Urbana',
            textposition = 'auto',
            text= dados1,
            marker=dict(color='silver'),  
            
            )
trace2 = go.Bar(
            x = label2,
            y = dados2,
            name='Rural',
            textposition = 'auto',
            text= dados2,
            marker=dict(color='seagreen'),  
            
            )

data = [trace1, trace2]
layout = go.Layout(barmode='group',yaxis=dict(title='Qtd'),xaxis=dict(title='Espécie', tickmode='linear'),title='Distribuição da Espécie por Clientela')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %%
# Distribuição da Espécie por Ano

label1 = df_aposentadorias[df_aposentadorias['Espécie']== '42-Ap Tempo Contrib Lops'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
label2 = df_aposentadorias[df_aposentadorias['Espécie']== '46-Ap Tempo Contrib Especial'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values 
label3 = df_aposentadorias[df_aposentadorias['Espécie']== 'Outras Ap Tempo Contrib'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].index.values
dados1 = df_aposentadorias[df_aposentadorias['Espécie']== '42-Ap Tempo Contrib Lops'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values
dados2 = df_aposentadorias[df_aposentadorias['Espécie']== '46-Ap Tempo Contrib Especial'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values
dados3 = df_aposentadorias[df_aposentadorias['Espécie']== 'Outras Ap Tempo Contrib'].groupby(['Ano']).sum()['Qte Benefícios Concedidos'].values

trace1 = go.Bar(
            x = label1,
            y = dados1,
            name='42-Ap Tempo Contrib Lops',
            #textposition = 'auto',
            #text= dados1,
            marker=dict(color='khaki'),  
            
            )

trace2 = go.Bar(
             x = label2,
            y = dados2,
            name='46-Ap Tempo Contrib Especial',
            #textposition = 'auto',
            #text=dados2,
            marker=dict(color='lightsteelblue'),  
            
            )

trace3 = go.Bar(
             x =label3,
            y = dados3,
            name='Outras Ap Tempo Contrib',
            #textposition = 'auto',
            #text=dados3,
            marker=dict(color='lightgreen'),  
            
            )

data = [trace1, trace2, trace3]
layout = go.Layout(barmode='stack', yaxis=dict(title='Qtd'),xaxis=dict(title='Ano', tickmode='linear'),title='Distribuição da Espécie por Ano')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )

# %% [markdown]
# # ******* Testes Abaixo ****************

# %%
STOP HERE
# Out:
#   File "<ipython-input-31-a6774c8535dd>", line 1
#     STOP HERE
#             ^
# SyntaxError: invalid syntax

# %%
df_aposentadorias.groupby('Ano').sum()['Vlr Benefícios Concedidos (R$)'].values,
# Out:
# (array([1.64653854e+08, 2.36049229e+08, 1.73014289e+08, 8.52542440e+07,
#         7.50621260e+07, 8.01730031e+07, 1.17393146e+08, 1.16419292e+08,
#         1.29458563e+08, 1.41611534e+08, 1.84662933e+08, 2.64766431e+08,
#         3.05005586e+08, 3.44862836e+08, 3.54442811e+08, 4.12540388e+08,
#         4.45677055e+08, 5.12894115e+08, 5.47816323e+08, 6.39701600e+08,
#         1.00296878e+09]),)

# %%
# Quantidade Benefícios Concedidos por Ano

trace1 = go.Bar(
            x = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].index.values,
            y = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].values,
            name='Quantidade',
            marker=dict( color='indianred'), 
            )


# Valor dos Benefícios Concedidos (R$)
trace2 = go.Bar(
            x = df_aposentadorias.groupby('Ano').sum()['Vlr Benefícios Concedidos (R$)'].index.values,
            y = df_aposentadorias.groupby('Ano').sum()['Vlr Benefícios Concedidos (R$)'].values,
            name='Valor (R$)',
            marker=dict(color='dodgerblue'),            
            )


fig = tools.make_subplots(rows=1, cols=2)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(title='Ditribuição dos Benefícios Concedidos por Ano', 
                         yaxis=dict(title='Quantidade'), 
                         yaxis2=dict(title='Valor (R$)'), 
                         xaxis1=dict(title='Ano', tickmode='linear' , tickangle=-45), 
                         xaxis2=dict(title='Ano', tickmode='linear' , tickangle=-45)
                    )
py.iplot(fig, filename='simple-subplot-with-annotations')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]

# %%
import plotly.tools as tools

# %%
df_aposentadorias.sort_values(by=['Sexo']).Sexo.unique()

# %%
df_aposentadorias.sort_values(by=['Sexo']).groupby('Sexo').sum()['Qte Benefícios Concedidos']

# %%
# Distribuição por Sexo
df_sexo =  df_aposentadorias.sort_values(by=['Sexo']).groupby('Sexo').sum()['Qte Benefícios Concedidos']
df_clientela =  df_aposentadorias.sort_values(by=['Clientela']).groupby('Clientela').sum()['Qte Benefícios Concedidos']

trace1 = go.Bar(
            x = df_sexo, 
            y = df_aposentadorias.sort_values(by=['Sexo']).Sexo.unique(), 
            textposition = 'auto',
            text=df_sexo,
            marker=dict(color=['pink', 'lightskyblue',]),  
            orientation = 'h',
    )

trace2 = go.Bar(
            x = df_clientela, 
            y = df_aposentadorias.sort_values(by=['Clientela']).Clientela.unique(), 
            textposition = 'auto',
            text=df_clientela,
            marker=dict(color=['green', 'gray']),  
            orientation = 'h',
    )


#Distribuição por Sexo
#labels = df_aposentadorias['Sexo']
#values = df_aposentadorias.groupby('Sexo').sum()['Qte Benefícios Concedidos']

#trace2 = go.Pie(labels=labels, values=values,               marker=dict(colors=['lightskyblue', 'pink']),                )


#layout = go.Layout(yaxis=dict(title='Sexo'),xaxis=dict(title='Qtd') ,title='Distribuição por Sexo',autosize=False,     width=800,     height=500 )

#fig = go.Figure(data=[trace], layout=layout, )

#py.iplot(fig, filename='basic_pie_chart')



fig = tools.make_subplots(rows=1, cols=2)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

#fig['layout'].update(height=600, width=800, title='i <3 annotations and subplots')
py.iplot(fig)

# %%
labels = df_aposentadorias['Espécie']
values = df_aposentadorias.groupby('Espécie').sum()['Qte Benefícios Concedidos']

trace11 = go.Pie(labels=labels, values=values)

py.iplot([trace11], filename='basic_pie_chart')

# %%
labels = df_aposentadorias['Clientela']
values = df_aposentadorias.groupby('Clientela').sum()['Qte Benefícios Concedidos']

trace21 = go.Pie(labels=labels, values=values)

py.iplot([trace21], filename='basic_pie_chart')

# %%
fig = {
    "data": [
        {
            "type": 'violin',
            "x": df_urbana["Espécie"],
            "y": df_urbana['Qte Benefícios Concedidos'],
            "legendgroup": 'Good Credit',
            "scalegroup": 'No',
            "name": 'Masculino',
            "side": 'negative',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'blue'
            }
        },
        {
            "type": 'violin',
            "x":  df_rural["Espécie"],
            "y": df_rural['Qte Benefícios Concedidos'],
            "legendgroup": 'Bad Credit',
            "scalegroup": 'No',
            "name": 'Feminino',
            "side": 'positive',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'green'
            }
        }
    ],
    "layout" : {
        "yaxis": {
            "zeroline": False,
        },
        "violingap": 0,
        "violinmode": "overlay"
    }
}


py.iplot(fig, filename = 'violin/split', validate = False)

# %%
trace0 = go.Box(
    x=df_masculino["Sexo"],
    y=df_masculino["Qte Benefícios Concedidos"],
    name='Masculino'
)

trace1 = go.Box(
      x=df_feminino["Sexo"],
    y=df_feminino["Qte Benefícios Concedidos"],
    name='Feminino'
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Valor Benefícios distribuidos por Sexo'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')

# %%
masculino1 = df_beneficio[df_beneficio["Sexo"]== 'Masculino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values
feminino1 = df_beneficio[df_beneficio["Sexo"]== 'Feminino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values

# %%
sns.distplot(masculino1);

# %%
#sns.distplot(df_aposentadorias['Qte Benefícios Concedidos']);
sns.distplot(feminino1);

# %%
sns.distplot(df_aposentadorias['Vlr Benefícios Concedidos (R$)']);

# %%
df_beneficio.groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values

# %%
df_beneficio = df_aposentadorias[df_aposentadorias['Qte Benefícios Concedidos'] > 0]
df_beneficio = df_beneficio[df_beneficio['Anos de Serviço do Segurado'] != 'Ignorado']
df_beneficio = df_beneficio[df_beneficio['Anos de Serviço do Segurado'] != '{ñ class}']
df_beneficio = df_beneficio.replace('Até 15 Anos', '0 a 15 Anos')

# Plota piramide da Distribuição Sexo por Anos de Serviço

label1 = df_beneficio['Anos de Serviço do Segurado'].unique()

masculino = df_beneficio[df_beneficio["Sexo"]== 'Masculino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values
feminino = df_beneficio[df_beneficio["Sexo"]== 'Feminino'].groupby(['Anos de Serviço do Segurado']).count()["Sexo"].values


layout = go.Layout(yaxis=go.layout.YAxis(title='Anos de Serviço'),
                   xaxis=go.layout.XAxis(title='Qtd'),
                   barmode='overlay',
                   bargap=0.1,
                  title='Distribuição Sexo por Anos de Serviço')


trace1 = go.Bar(y = label1,
            x = masculino *-1,
            name='Masculino',
            orientation='h',
            hoverinfo='x',
            marker=dict(color='lightskyblue'),  
            )
trace2 = go.Bar(y =label1,
            x = feminino,            
            name='Feminino',
            orientation='h',
            text=-1 * dados2.astype('int'),
            hoverinfo='text',
            marker=dict(color='pink'),  
            )

data = [trace1, trace2]

py.iplot( dict(data=data, layout=layout) )

# %%
df_aposentadorias.groupby(['Ano', 'Sexo']).mean()

# %%
df_beneficio['Anos de Serviço do Segurado'].unique()

# %%
df_aposentadorias[df_aposentadorias["Sexo"]== 'Masculino'].groupby(['Anos de Serviço do Segurado']).count()['Sexo'].values

# %%
df_aposentadorias[df_aposentadorias['Espécie']== '42-Ap Tempo Contrib Lops']['Espécie'].value_counts().index

# %%
df_aposentadorias['Anos de Serviço do Segurado'].unique()

# %%
df = df_aposentadorias.groupby(['Ano', 'Sexo']).sum()['Qte Benefícios Concedidos']

# %%
df_aposentadorias['Espécie'].unique()

# %%
df_aposentadorias.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values

# %%
#  Histograma

trace1 = go.Histogram(           
            x = df_aposentadorias.groupby(['Anos de Serviço do Segurado']).sum()['Qte Benefícios Concedidos'].values,
            histnorm='probability',
            )

data = [trace1]
layout = go.Layout(xaxis=dict(title=''),title='')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='normalized histogram' )

# %%
df_aposentadorias["Ano"].value_counts().sort_index().values

# %%
df_aposentadorias.groupby('Anos de Serviço do Segurado').count();

# %%
df_aposentadorias["Ano"].value_counts().sort_index().index.values

# %%
df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].index.values,

# %%
# Distribuição por Ano

trace1 = go.Histogram(
            x = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].index.values,
            y = df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].values,
            histnorm='probability',
            name='Ano',
            #textposition = 'auto',
            #text=df_aposentadorias.groupby('Ano').sum()['Qte Benefícios Concedidos'].values,  
            )

data = [trace1]
layout = go.Layout(yaxis=dict(title='Qtd'),xaxis=dict(title='Ano', tickmode='linear'),title='Distribuição por Ano')
fig = go.Figure(data=data, layout=layout, )
py.iplot(fig, filename='grouped-bar' )
